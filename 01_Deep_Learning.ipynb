# %% [markdown]
# <a href="https://colab.research.google.com/github/GitGetMat/python-dl-course-unifr/blob/main/01_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DEEP LEARNING WITH PYTHON
# ## _FROM TABULAR TO MULTIMEDIA_
#
# ### UniFr Winter School in Data Analytics & Machine Learning
# Fribourg, 11-13 February 2026
#
# with [Christian Kauth](https://www.linkedin.com/in/ckauth/)

# %% [markdown]
# # Table of Contents
#
# _⚠️ Links to other notebooks will become active at the start of this lecture._
#
# 1. [Deep Learning](https://colab.research.google.com/drive/1mkn-6WvMvH13gPZeobQlewNOQ4M_0fzK?usp=sharing)
# 2. [Perceptron]()
# 3. [Stochastic Gradient Descent]()
# 4. [Convolutional Neural Networks]()
# 5. [Handwritten Digits ✒️]()
# 6. [Satellite Images 🌍]()
# 7. [Transfer Learning 🤗]()
# 8. [Vision AIs 🦪]()
# 9. [Natural Language Processing]()
# 10. [Transformers]()
# 11. [Job Postings 💼]()
# 12. [Named Entity Recognition]()
# 13. [Agents]()

# %% [markdown]
# # Take-Home Exam 🚀
#
# ## Grade & ECTS
# - Grades will range from **1 (lowest)** to **6 (highest)**, in increments of 0.25.
# - A passing grade of **4.0 or higher** entitles you to **1.5 ECTS**.
#
# ## Team
# With your skills in deep learning and multi-modal AI (e.g., vision, text, audio, etc.), the possibilities are endless. You can work **individually** or in teams of up to **3 members**.
#
# ## Submission
# - Submit **one Jupyter notebook**, including the names of all team members in the file name, following this format: `DL_JohnDoe_AliceSmith_MaryJohnson.ipynb`.
# - The notebook will be executed prior to grading. The **maximum runtime** allowed is **10 minutes per team member**, meaning a team of three can take up to 30 minutes.
# - Set the notebook runtime type to either **T4 GPU** or **CPU**.
#
# ## Structure
# Your notebook should include the following components:
#
# 1. **Abstract**
#    - Describe your **AI-powered app**: What did you build, and why is it important (either to you or the broader world)?
#
# 2. **Dataset Preparation**
#    - Download, clean, and split a publicly available dataset into **training, validation, and test sets**.
#    - You may assume the following environment variables are set up on the grading system: `KAGGLE_KEY`, `KAGGLE_USER` and `HF_TOKEN`.
#
# 3. **Model Creation**
#    - Develop one neural network (NN) model using frameworks like **Keras**, **TensorFlow**, or **Hugging Face**.
#    - You can choose to train from scratch, fine-tune, or use transfer learning.
#
# 4. **Model Evaluation**
#    - Evaluate the model’s performance on the test set.
#    - Provide a brief discussion of the results.
#
# 5. **Model Card**
#    - Write a concise [model card](https://huggingface.co/docs/hub/en/model-cards) that summarizes your model.
#
# 6. **Multi-Modal Integration**
#    - Think of how a publicly available model from another modality could complement your model.
#    - You may assume the following environment variables are available: `HF_TOKEN` and `OPENAI_API_KEY`.
#
# 7. **Gradio App**
#    - Wrap your models into a **Gradio app** that allows user interaction.
#    - Include example inputs to help users get started quickly.
#
# 8. **Outlook**
#    - Briefly discuss what you would have done if you had additional time (e.g., another month).
#
# ## Deadline
# - **Sunday, March 15th, 23:59** (no further extensions).
# - If you tend to submit late, consider setting an earlier personal deadline to ensure timely submission.
# - Submit by email to `christian.kauth@unifr.ch`
#
# ## Resources
# ### Data
# - [Kaggle](https://www.kaggle.com/datasets)
# - [Hugging Face](https://huggingface.co/datasets)
#
# ### Models
# - [Hugging Face](https://huggingface.co/models)
# - [OpenAI](https://platform.openai.com/docs/models)
#
# ### Deep Learning
# - [Keras](https://keras.io/)
# - [TensorFlow](https://www.tensorflow.org/)
#
# ### App Development
# - [Gradio](https://www.gradio.app/)
#
# <hr>

# %% [markdown]
# # Artificial Neuron (Perceptron)

# %% [markdown]
# <img src="https://miro.medium.com/max/1220/1*SJPacPhP4KDEB1AdhOFy_Q.png" alt="drawing" width="500"/>

# %% [markdown]
# ## Weights $w_i$
#
# $ potential = bias + \Sigma_{i=1}^n w_i \cdot in_i$

# %% [markdown]
# ❓ What does this equation remind you of?

# %% [markdown]
# ## Activation $f(\cdot)$
#
# $out = f(potential)$

# %% [markdown]
# ### Sigmoid:
# $f(x) = \frac{1}{1 + e^{-x}} \in ]0, 1[$

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from matplotlib import pyplot as plt

# %%
activation_layer = layers.Activation('sigmoid')
x = tf.linspace(-30.0, 30.0, 100)
y = activation_layer(x)

fig, ax = plt.subplots(figsize=(10, 6))
plt.plot(x, y)
plt.grid()
plt.show()

# %% [markdown]
# ### Hypoerbolic tangent
# $f(x) = \tanh(x) \in ]-1, 1[$

# %%
activation_layer = layers.Activation('tanh')
x = tf.linspace(-30.0, 30.0, 100)
y = activation_layer(x)

fig, ax = plt.subplots(figsize=(10, 6))
plt.plot(x, y)
plt.grid()
plt.show()

# %% [markdown]
# ### Rectifier
# $f(x) = max(0, x) \in [0, \rightarrow$

# %%
activation_layer = layers.Activation('relu')
x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x)

fig, ax = plt.subplots(figsize=(10, 6))
plt.plot(x, y)
plt.grid()
plt.show()

# %% [markdown]
# # Neural Network (Multilayer Perceptron)
#
# ### Layers
#
# - Neurons are arranged in layers
#
# ### Network
#
# - Layers are stacked into a neural network

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Artificial_neural_network.svg/1280px-Artificial_neural_network.svg.png" alt="drawing" width="500"/>

# %% [markdown]
# ## Universal Approximation Theorem

# %%
# %%html
# <iframe src="https://en.wikipedia.org/wiki/Universal_approximation_theorem" width="1000px" height="600px"/>
# Out:
# <iframe src="https://en.wikipedia.org/wiki/Universal_approximation_theorem" width="1000px" height="600px"/>

# %% [markdown]
# ## Training
#
# ### Data Preparation
#
# - Inputs must be numerical and in a pretty defined range
#
#   - Numbers can be normalized or standardized
#
#   - Pixel / Sound intensity are numbers
#
#   - Categorical data can be One-Hot encoded
#
#   - Texts (vocabulary) can be indexed (e.g. bag of words) or word embeddings (thank you OpenAI!) are used
#
#   - Graphs... be a little creative

# %% [markdown]
# ### Stochastic Gradient Descent

# %% [markdown]
# #### Forward Pass
#
# <img src="https://i.makeagif.com/media/8-24-2018/P7zznD.gif" width="1000px"/>

# %% [markdown]
# #### Backpropagation Pass
#
# <img src="https://developer-blogs.nvidia.com/wp-content/uploads/2022/02/DS-Guide-to-Gradient-Descent_Pic5.gif" width="1000"/>

# %% [markdown]
# ### Weight Updates
#
# To make the learning process less chaotic and more stable, one may use:
#
# - Batch learning
#
# - Momentum
#
# - Learning Rate Decay
#
# 🔮 if you don't know where to start, use the `Adam` optimizer

# %% [markdown]
# ## Prediction
#
# - To make a prediction, you just need the network topology and all the weights.

# %% [markdown]
# #### Inference
#
# <img src="https://kevintshoemaker.github.io/NRES-746/media/neuralNet.gif" width="1000"/>

# %% [markdown]
# # Deep Learning Frameworks
#
# [Which deep learning framework is the best?](https://towardsdatascience.com/which-deep-learning-framework-is-the-best-eb51431c39a)

# %% [markdown]
# ## Keras
# [Deep Learning for Humans](https://keras.io/)

# %% [markdown]
# ## Tensorflow
#
# [An end-to-end open source machine learning platform](https://www.tensorflow.org/)

# %% [markdown]
# ## Pytorch
# [From research to production](https://pytorch.org/)

# %% [markdown]
# # UP NEXT
#
# [Perceptron]()
#
# _⚠️ Links to other notebooks will become active at the start of this lecture._
